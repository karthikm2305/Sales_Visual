# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikm2305/Sales_Visual/blob/main/SALES_CO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
sales1=pd.read_csv('/content/advertising.csv')
sales1
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
sales1.head(50)
# Out:
#        TV  Radio  Newspaper  Sales
# 0   230.1   37.8       69.2   22.1
# 1    44.5   39.3       45.1   10.4
# 2    17.2   45.9       69.3   12.0
# 3   151.5   41.3       58.5   16.5
# 4   180.8   10.8       58.4   17.9
# 5     8.7   48.9       75.0    7.2
# 6    57.5   32.8       23.5   11.8
# 7   120.2   19.6       11.6   13.2
# 8     8.6    2.1        1.0    4.8
# 9   199.8    2.6       21.2   15.6
# 10   66.1    5.8       24.2   12.6
# 11  214.7   24.0        4.0   17.4
# 12   23.8   35.1       65.9    9.2
# 13   97.5    7.6        7.2   13.7
# 14  204.1   32.9       46.0   19.0
# 15  195.4   47.7       52.9   22.4
# 16   67.8   36.6      114.0   12.5
# 17  281.4   39.6       55.8   24.4
# 18   69.2   20.5       18.3   11.3
# 19  147.3   23.9       19.1   14.6
# 20  218.4   27.7       53.4   18.0
# 21  237.4    5.1       23.5   17.5
# 22   13.2   15.9       49.6    5.6
# 23  228.3   16.9       26.2   20.5
# 24   62.3   12.6       18.3    9.7
# 25  262.9    3.5       19.5   17.0
# ...

# %%
sales1.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sales1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
sales1.shape
# Out:
# (200, 4)

# %%
sales1['TV'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.displot(sales1['Radio'])

# %%
sns.jointplot(x='TV',y='Sales',data=sales1,kind='reg')

# %%
sales1.duplicated().any()
# Out:
# False

# %%
sns.pairplot(sales1,hue='Sales')

# %%
sales1["Sales"].value_counts()
# Out:
# 11.9    5
# 16.7    5
# 20.7    4
# 11.0    3
# 11.3    3
#        ..
# 13.4    1
# 24.2    1
# 8.1     1
# 5.5     1
# 25.5    1
# Name: Sales, Length: 121, dtype: int64

# %%
import seaborn as sns
sns.countplot(x="Sales",data=sales1.head(25))
# Out:
# <Axes: xlabel='Sales', ylabel='count'>

# %%
sns.pairplot(sales1, vars=['TV', 'Radio', 'Sales'], kind='scatter')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(sales1[['TV']], sales1['Sales'], test_size=0.3, random_state=0)
print(x_train)
# Out:
#         TV
# 131  265.2
# 96   197.6
# 181  218.5
# 19   147.3
# 153  171.3
# ..     ...
# 67   139.3
# 192   17.2
# 117   76.4
# 47   239.9
# 172   19.6
#
# [140 rows x 1 columns]

# %%
print(y_train)
# Out:
# 131    17.7
# 96     16.7
# 181    17.2
# 19     14.6
# 153    16.0
#        ...
# 67     13.4
# 192     5.9
# 117     9.4
# 47     23.2
# 172     7.6
# Name: Sales, Length: 140, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
res=model.predict(x_test)
print(res)
# Out:
# [10.93127621  9.88042193 12.09159447 22.99968079 16.45920756 10.21976029
#   7.6199906  20.28497391  8.4464437  17.95886418 21.44529217 11.91645209
#  15.71485245 17.42249065 11.32534656 13.72260788 21.68063975  7.18213465
#  11.23230217 18.82362968 22.88474361 14.82272095 16.72739433 14.35202581
#  10.07198391 13.88133066 16.20744039 18.36388094 19.40378881  8.51759529
#  10.85465142 18.03001578 22.50709285 20.3725451   7.86628457  8.16731053
#  10.40584907 17.03936669 10.88749061  8.51212209  9.16343282  8.86788005
#  14.96502414 18.61564811 18.93309367 12.76479799  7.6145174   8.06879294
#  14.02363385 12.86878878 13.15339515 19.70481478 21.03480222 17.26376787
#   9.59034237 10.55362545 23.17482317 16.58509115 18.22705095  7.54336581]

# %%
plt.plot(res)

# %%
from sklearn.metrics import r2_score

train_pred = model.predict(x_train)
test_pred = model.predict(x_test)

r2_train = r2_score(y_train, train_pred)
r2_test = r2_score(y_test, test_pred)

print("training pred:", r2_train * 100)
# Out:
# training pred: 80.5941153711277

# %%
print("test pred:", r2_test * 100)
# Out:
# test pred: 81.50168765722069

# %%
x=sales1[['TV','Radio','Newspaper']].values
y=sales1[['Sales']].values
print(x)
# Out:
# [[230.1  37.8  69.2]
#  [ 44.5  39.3  45.1]
#  [ 17.2  45.9  69.3]
#  [151.5  41.3  58.5]
#  [180.8  10.8  58.4]
#  [  8.7  48.9  75. ]
#  [ 57.5  32.8  23.5]
#  [120.2  19.6  11.6]
#  [  8.6   2.1   1. ]
#  [199.8   2.6  21.2]
#  [ 66.1   5.8  24.2]
#  [214.7  24.    4. ]
#  [ 23.8  35.1  65.9]
#  [ 97.5   7.6   7.2]
#  [204.1  32.9  46. ]
#  [195.4  47.7  52.9]
#  [ 67.8  36.6 114. ]
#  [281.4  39.6  55.8]
#  [ 69.2  20.5  18.3]
#  [147.3  23.9  19.1]
#  [218.4  27.7  53.4]
#  [237.4   5.1  23.5]
#  [ 13.2  15.9  49.6]
#  [228.3  16.9  26.2]
#  [ 62.3  12.6  18.3]
#  [262.9   3.5  19.5]
#  [142.9  29.3  12.6]
#  [240.1  16.7  22.9]
#  [248.8  27.1  22.9]
#  [ 70.6  16.   40.8]
#  [292.9  28.3  43.2]
#  [112.9  17.4  38.6]
#  [ 97.2   1.5  30. ]
#  [265.6  20.    0.3]
#  [ 95.7   1.4   7.4]
#  [290.7   4.1   8.5]
#  [266.9  43.8   5. ]
#  [ 74.7  49.4  45.7]
#  [ 43.1  26.7  35.1]
#  [228.   37.7  32. ]
#  [202.5  22.3  31.6]
#  [177.   33.4  38.7]
#  [293.6  27.7   1.8]
# ...

# %%
print(y)
# Out:
# [[22.1]
#  [10.4]
#  [12. ]
#  [16.5]
#  [17.9]
#  [ 7.2]
#  [11.8]
#  [13.2]
#  [ 4.8]
#  [15.6]
#  [12.6]
#  [17.4]
#  [ 9.2]
#  [13.7]
#  [19. ]
#  [22.4]
#  [12.5]
#  [24.4]
#  [11.3]
#  [14.6]
#  [18. ]
#  [17.5]
#  [ 5.6]
#  [20.5]
#  [ 9.7]
#  [17. ]
#  [15. ]
#  [20.9]
#  [18.9]
#  [10.5]
#  [21.4]
#  [11.9]
#  [13.2]
#  [17.4]
#  [11.9]
#  [17.8]
#  [25.4]
#  [14.7]
#  [10.1]
#  [21.5]
#  [16.6]
#  [17.1]
#  [20.7]
#  [17.9]
#  [ 8.5]
#  [16.1]
#  [10.6]
#  [23.2]
#  [19.8]
#  [ 9.7]
#  [16.4]
#  [10.7]
#  [22.6]
#  [21.2]
#  [20.2]
#  [23.7]
#  [ 5.5]
#  [13.2]
#  [23.8]
#  [18.4]
#  [ 8.1]
#  [24.2]
#  [20.7]
#  [14. ]
#  [16. ]
#  [11.3]
#  [11. ]
#  [13.4]
#  [18.9]
#  [22.3]
#  [18.3]
#  [12.4]
#  [ 8.8]
#  [11. ]
#  [17. ]
#  [ 8.7]
#  [ 6.9]
#  [14.2]
#  [ 5.3]
#  [11. ]
#  [11.8]
#  [17.3]
#  [11.3]
#  [13.6]
#  [21.7]
#  [20.2]
#  [12. ]
#  [16. ]
#  [12.9]
#  [16.7]
#  [14. ]
#  [ 7.3]
#  [19.4]
#  [22.2]
#  [11.5]
#  [16.9]
#  [16.7]
#  [20.5]
#  [25.4]
#  [17.2]
# ...

# %% [markdown]
# THANK YOU
